# %% [markdown]
# <a href="https://colab.research.google.com/github/syamalaroopamukkavilli/Python_Code/blob/Py_Sessions/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Introduction to Python

# %%
num=3
print(num)
num
# Out:
# 3
# 3

# %%
num
# Out:
# 3
